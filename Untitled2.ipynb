# %% [markdown]
# <a href="https://colab.research.google.com/github/AndiKotak/AndiKotak.github.io/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Load and preprocess CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images = train_images.astype("float32") / 255.0
test_images = test_images.astype("float32") / 255.0
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Define a function to create and compile a CNN model
def create_model(activation_function):
  model = models.Sequential([
      layers.Conv2D(32, (3, 3), activation=activation_function, input_shape=(32, 32, 3)),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(64, (3, 3), activation=activation_function),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(64, (3, 3), activation=activation_function),
      layers.Flatten(),
      layers.Dense(64, activation=activation_function),
      layers.Dense(10, activation='softmax') #Softmax for output layer
  ])
  model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
# List of activation function to compare
activation_function = ['linear', 'sigmoid', 'tanh', 'relu', 'leaky_relu']
results = {}

# %%
# Train and evaluate models with different activation functions
for activation in activation_function:
  print(f"\nTraining model with {activation} activation...")
  if activation == 'leaky_relu':
    model = models.Sequential([
      layers.Conv2D(32, (3, 3), input_shape=(32, 32, 3)),
      layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(64, (3, 3)),
      layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(64, (3, 3)),
      layers.Activation(tf.keras.layers.LeakyReLU(alpha=0.1)),
      layers.Flatten(),
      layers.Dense(64),
      layers.LeakyReLU(alpha=0.1),
      layers.Dense(10, activation='softmax')
      ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
  else:
    model = create_model(activation)

    history = model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_split=0.2, verbose=2)
    test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
# Out:
# Training model with linear activation...
# Epoch 1/10
# 625/625 - 71s - 113ms/step - accuracy: 0.4690 - loss: 1.5048 - val_accuracy: 0.5597 - val_loss: 1.2811
# Epoch 2/10
# 625/625 - 68s - 109ms/step - accuracy: 0.5741 - loss: 1.2293 - val_accuracy: 0.5976 - val_loss: 1.1946
# Epoch 3/10
# 625/625 - 78s - 125ms/step - accuracy: 0.6080 - loss: 1.1380 - val_accuracy: 0.6139 - val_loss: 1.1465
# Epoch 4/10
# 625/625 - 53s - 84ms/step - accuracy: 0.6308 - loss: 1.0790 - val_accuracy: 0.6209 - val_loss: 1.1240
# Epoch 5/10
# 625/625 - 81s - 129ms/step - accuracy: 0.6475 - loss: 1.0301 - val_accuracy: 0.6220 - val_loss: 1.1208
# Epoch 6/10
# 625/625 - 52s - 83ms/step - accuracy: 0.6633 - loss: 0.9891 - val_accuracy: 0.6231 - val_loss: 1.1198
# Epoch 7/10
# 625/625 - 81s - 130ms/step - accuracy: 0.6744 - loss: 0.9542 - val_accuracy: 0.6223 - val_loss: 1.1261
# Epoch 8/10
# 625/625 - 82s - 131ms/step - accuracy: 0.6858 - loss: 0.9230 - val_accuracy: 0.6216 - val_loss: 1.1384
# Epoch 9/10
# 625/625 - 84s - 134ms/step - accuracy: 0.6956 - loss: 0.8943 - val_accuracy: 0.6220 - val_loss: 1.1399
# Epoch 10/10
# 625/625 - 51s - 82ms/step - accuracy: 0.7044 - loss: 0.8681 - val_accuracy: 0.6256 - val_loss: 1.1381
#
# Training model with sigmoid activation...
# Epoch 1/10
# 625/625 - 55s - 88ms/step - accuracy: 0.2064 - loss: 2.1304 - val_accuracy: 0.2963 - val_loss: 1.9398
# Epoch 2/10
# 625/625 - 82s - 130ms/step - accuracy: 0.3368 - loss: 1.8351 - val_accuracy: 0.3567 - val_loss: 1.7715
# Epoch 3/10
# 625/625 - 83s - 133ms/step - accuracy: 0.3932 - loss: 1.6788 - val_accuracy: 0.4145 - val_loss: 1.6233
# Epoch 4/10
# 625/625 - 79s - 127ms/step - accuracy: 0.4314 - loss: 1.5764 - val_accuracy: 0.4405 - val_loss: 1.5512
# Epoch 5/10
# 625/625 - 84s - 134ms/step - accuracy: 0.4543 - loss: 1.5149 - val_accuracy: 0.4542 - val_loss: 1.5191
# Epoch 6/10
# 625/625 - 84s - 134ms/step - accuracy: 0.4730 - loss: 1.4711 - val_accuracy: 0.4678 - val_loss: 1.4877
# Epoch 7/10
# 625/625 - 80s - 129ms/step - accuracy: 0.4855 - loss: 1.4336 - val_accuracy: 0.4816 - val_loss: 1.4470
# Epoch 8/10
# 625/625 - 56s - 89ms/step - accuracy: 0.4980 - loss: 1.3984 - val_accuracy: 0.4908 - val_loss: 1.4179
# Epoch 9/10
# 625/625 - 80s - 128ms/step - accuracy: 0.5097 - loss: 1.3643 - val_accuracy: 0.4973 - val_loss: 1.3940
# Epoch 10/10
# 625/625 - 82s - 131ms/step - accuracy: 0.5219 - loss: 1.3309 - val_accuracy: 0.5084 - val_loss: 1.3727
#
# Training model with tanh activation...
# Epoch 1/10
# 625/625 - 59s - 94ms/step - accuracy: 0.4683 - loss: 1.4988 - val_accuracy: 0.5608 - val_loss: 1.2452
# Epoch 2/10
# 625/625 - 55s - 87ms/step - accuracy: 0.5860 - loss: 1.1815 - val_accuracy: 0.6052 - val_loss: 1.1231
# Epoch 3/10
# 625/625 - 83s - 134ms/step - accuracy: 0.6277 - loss: 1.0664 - val_accuracy: 0.6232 - val_loss: 1.0802
# Epoch 4/10
# 625/625 - 80s - 128ms/step - accuracy: 0.6529 - loss: 0.9960 - val_accuracy: 0.6273 - val_loss: 1.0742
# Epoch 5/10
# 625/625 - 82s - 132ms/step - accuracy: 0.6744 - loss: 0.9363 - val_accuracy: 0.6410 - val_loss: 1.0305
# Epoch 6/10
# 625/625 - 83s - 133ms/step - accuracy: 0.6952 - loss: 0.8808 - val_accuracy: 0.6462 - val_loss: 1.0284
# Epoch 7/10
# 625/625 - 55s - 88ms/step - accuracy: 0.7150 - loss: 0.8286 - val_accuracy: 0.6466 - val_loss: 1.0376
# Epoch 8/10
# 625/625 - 55s - 87ms/step - accuracy: 0.7330 - loss: 0.7785 - val_accuracy: 0.6420 - val_loss: 1.0578
# Epoch 9/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7460 - loss: 0.7419 - val_accuracy: 0.6354 - val_loss: 1.0888
# Epoch 10/10
# 625/625 - 54s - 87ms/step - accuracy: 0.7583 - loss: 0.7079 - val_accuracy: 0.6410 - val_loss: 1.0744
#
# Training model with relu activation...
# Epoch 1/10
# 625/625 - 54s - 87ms/step - accuracy: 0.4029 - loss: 1.6196 - val_accuracy: 0.5189 - val_loss: 1.3566
# Epoch 2/10
# 625/625 - 54s - 86ms/step - accuracy: 0.5436 - loss: 1.2741 - val_accuracy: 0.5868 - val_loss: 1.1819
# Epoch 3/10
# 625/625 - 80s - 128ms/step - accuracy: 0.6055 - loss: 1.1173 - val_accuracy: 0.6227 - val_loss: 1.0780
# Epoch 4/10
# 625/625 - 52s - 83ms/step - accuracy: 0.6405 - loss: 1.0200 - val_accuracy: 0.6368 - val_loss: 1.0272
# Epoch 5/10
# 625/625 - 81s - 130ms/step - accuracy: 0.6694 - loss: 0.9413 - val_accuracy: 0.6525 - val_loss: 0.9916
# Epoch 6/10
# 625/625 - 51s - 82ms/step - accuracy: 0.6924 - loss: 0.8751 - val_accuracy: 0.6566 - val_loss: 0.9846
# Epoch 7/10
# 625/625 - 82s - 132ms/step - accuracy: 0.7115 - loss: 0.8206 - val_accuracy: 0.6626 - val_loss: 0.9778
# Epoch 8/10
# 625/625 - 83s - 133ms/step - accuracy: 0.7282 - loss: 0.7745 - val_accuracy: 0.6646 - val_loss: 0.9828
# Epoch 9/10
# 625/625 - 82s - 131ms/step - accuracy: 0.7443 - loss: 0.7324 - val_accuracy: 0.6696 - val_loss: 0.9775
# Epoch 10/10
# 625/625 - 50s - 80ms/step - accuracy: 0.7596 - loss: 0.6938 - val_accuracy: 0.6826 - val_loss: 0.9528
#
# Training model with leaky_relu activation...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Store history, loss, accuracy, and confusion matrix
y_pred = model.predict(test_images)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

print(f"y_true shape: {y_true.shape}, y_pred_classes shape: {y_pred_classes.shape}")

conf_matrix = confusion_matrix(y_true, y_pred_classes)
results[activation] = (history, test_loss, test_acc, conf_matrix)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# y_true shape: (10000,), y_pred_classes shape: (10000,)

# %%
# Plot the result for accuracy and loss
plt.figure(figsize=(16, 6))

# %%
# Plot training accuracy
plt.subplot(1, 2, 1)
for activation, (history, _, _, _) in results.items():
  plt.plot(history.history['accuracy'], label=f'{activation} (train)')
  plt.title('Training Accuracy for Different Activation Functions on CIFAR-10')

# %%
# Plot training loss
plt.subplot(1, 2, 2)
for activation, (history, _, _, _) in results.items():
  plt.plot(history.history['loss'], label=f'{activation} (train)')
  plt.title('Training Loss for Different Activation Functions on CIFAR-10')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
# Display confusion matrix for each activation function
for activation, (_, _, test_acc, conf_matrix) in results.items():
  print(f'\nTest accuracy with {activation}: {test_acc:4f}')
  plt.figure(figsize=(8, 6))
  sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=[f'Class {i}' for i in range(10)]),
  yticklabels=[f'Class {i}' for i in range(10)]
  plt.title(f'Confusion Matrix for {activation.capitalize()} Activation on CIDAR-10')
  plt.xlabel('Predicted Labels')
  plt.ylabel('True Labels')
  plt.show()
# Out:
# Test accuracy with leaky_relu: 0.681400
